# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv("/Users/henrilehodey/code/jojibou/invesscience/raw_data/founders.csv")
df
df = df.rename(columns=())
# Out:
#       person_object_id         permalink   normalized_name  \
# 0                 p:10   mark-zuckerberg   mark zuckerberg
# 1              p:25830        ben-padnos        ben padnos
# 2             p:258233  subba-rao-ambati  subba rao ambati
# 3             p:258253  enrico-fiorentin  enrico fiorentin
# 4             p:258257  mark-de-quervain  mark de quervain
# ...                ...               ...               ...
# 53827         p:185880        paul-meyer        paul meyer
# 53828         p:252514     aashish-kumar     aashish kumar
# 53829         p:134554       thomas-fast       thomas fast
# 53830          p:58971       paul-parisi       paul parisi
# 53831          p:99998      adam-neumann      adam neumann
#
#                       api_path                 web_path  \
# 0       people/mark-zuckerberg   person/mark-zuckerberg
# 1            people/ben-padnos        person/ben-padnos
# 2      people/subba-rao-ambati  person/subba-rao-ambati
# ...

# %% [markdown]
# # keeping women

# %%
df_women = df[~df.gender.isin(Female)]
df_women.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-c3fec9b54b85> in <module>
# ----> 1 df_women = df[~df.gender.isin(Female)]
#       2 df_women.shape
#
# NameError: name 'Female' is not defined
