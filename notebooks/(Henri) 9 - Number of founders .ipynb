# %% [markdown]
# # Filtering

# %%
# !pip install pandas 
# !pip install numpy

# %%
import pandas as pd
import numpy as np
# Out:
# /Users/henrilehodey/.pyenv/versions/3.7.7/envs/invesscience/lib/python3.7/site-packages/pandas/compat/__init__.py:120: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
df = pd.read_csv("/Users/henrilehodey/code/jojibou/invesscience/raw_data/relationships.csv")
df
# Out:
#         relationship_id person_object_id relationship_object_id    start_at  \
# 0                     1              p:2                    c:1         NaN
# 1                     2              p:3                    c:1         NaN
# 2                     3              p:4                    c:3         NaN
# 3                     4              p:5                    c:3  2006-03-01
# 4                     6              p:7                    c:4  2005-07-01
# ...                 ...              ...                    ...         ...
# 402873           480903         p:268527               c:286218  2005-01-01
# 402874           480906         p:268597                c:12612         NaN
# 402875           480907         p:268528               c:286152         NaN
# 402876           480908         p:268528               c:286220         NaN
# 402877           480909         p:268528               c:286221         NaN
#
#             end_at  is_past  \
# ...

# %% [markdown]
# # keeping founders

# %%
founders = df['founder']==True

# %%
founders.head()
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# Name: founder, dtype: bool

# %%
df_filter = df[founders]
print(df_filter.shape)
# Out:
# (70465, 8)

# %%
df_filter
# Out:
#         relationship_id person_object_id relationship_object_id    start_at  \
# 0                     1              p:2                    c:1         NaN
# 7                     9             p:10                    c:5         NaN
# 8                    10             p:11                    c:5         NaN
# 11                   13             p:14                    c:5  1993-07-04
# 12                   14             p:16                 c:7299         NaN
# ...                 ...              ...                    ...         ...
# 402722           480741          p:29245               c:286154  2004-01-01
# 402773           480794         p:254302               c:286157         NaN
# 402775           480796         p:254302               c:286160         NaN
# 402776           480797         p:268562               c:286160         NaN
# 402865           480895         p:268590               c:286215         NaN
#
# ...

# %% [markdown]
# # group by company id and count

# %%
founder_count = df_filter.groupby('relationship_object_id', as_index = False )['person_object_id'].count()

# %%
founder_count
# Out:
#       relationship_object_id  person_object_id
# 0                        c:1                 2
# 1                       c:10                 3
# 2                      c:100                 3
# 3                    c:10002                 1
# 4                   c:100062                 2
# ...                      ...               ...
# 46302                  f:990                 2
# 46303                 f:9916                 1
# 46304                  f:992                 1
# 46305                 f:9969                 1
# 46306                  f:998                 1
#
# [46307 rows x 2 columns]

# %%
founder_count.rename({"relationship_object_id": "company_id"}, inplace=True)

# %%
founder_count
# Out:
#       relationship_object_id  person_object_id
# 0                        c:1                 2
# 1                       c:10                 3
# 2                      c:100                 3
# 3                    c:10002                 1
# 4                   c:100062                 2
# ...                      ...               ...
# 46302                  f:990                 2
# 46303                 f:9916                 1
# 46304                  f:992                 1
# 46305                 f:9969                 1
# 46306                  f:998                 1
#
# [46307 rows x 2 columns]

# %% [markdown]
# # Left merge to company table

# %%
companies = pd.read_csv("/Users/henrilehodey/code/jojibou/invesscience/raw_data/companies.csv")
companies.head()
# Out:
#         id                name     normalized_name  \
# 0      c:1            Wetpaint            wetpaint
# 1     c:10             Flektor             flektor
# 2    c:100               There               there
# 3  c:10000             MYWEBBO             mywebbo
# 4  c:10001  THE Movie Streamer  the movie streamer
#
#                      permalink    category_code     status  founded_at  \
# 0            /company/wetpaint              web  operating  2005-10-17
# 1             /company/flektor      games_video   acquired         NaN
# 2               /company/there      games_video   acquired         NaN
# 3             /company/mywebbo  network_hosting  operating  2008-07-26
# 4  /company/the-movie-streamer      games_video  operating  2008-07-26
#
#   closed_at                 homepage_url twitter_username  ...         city  \
# 0       NaN      http://wetpaint-inc.com  BachelrWetpaint  ...      Seattle
# ...

# %%
companies.rename({"id": "company_id"})
# Out:
#              id                name     normalized_name  \
# 0           c:1            Wetpaint            wetpaint
# 1          c:10             Flektor             flektor
# 2         c:100               There               there
# 3       c:10000             MYWEBBO             mywebbo
# 4       c:10001  THE Movie Streamer  the movie streamer
# ...         ...                 ...                 ...
# 196548  c:99940           Webgility           webgility
# 196549   c:9995              FohBoh              fohboh
# 196550   c:9996                 CSC                 csc
# 196551   c:9997      Top-candidate      top candidate
# 196552   c:9998      Closet Couture      closet couture
#
#                           permalink     category_code     status  founded_at  \
# 0                 /company/wetpaint               web  operating  2005-10-17
# 1                  /company/flektor       games_video   acquired         NaN
# ...

# %%
how_many_founders = pd.merge(companies, founder_count, how='left', on='company_id')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-e5de40258a08> in <module>
# ----> 1 how_many_founders = pd.merge(companies, founder_count, how='left', on='company_id')
#       2
#       3
#
# ~/.pyenv/versions/3.7.7/envs/invesscience/lib/python3.7/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      85         copy=copy,
#      86         indicator=indicator,
# ---> 87         validate=validate,
#      88     )
#      89     return op.get_result()
#
# ~/.pyenv/versions/3.7.7/envs/invesscience/lib/python3.7/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     650             self.right_join_keys,
# ...
