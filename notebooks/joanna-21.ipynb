# %% [markdown]
# # 21 - Clean up degree types

# %%
import pandas as pd
import numpy as np
import os

# %%
degrees = pd.read_csv(os.path.join('..',"raw_data","degrees.csv"))

# %%
degrees.head()
# Out:
#    id object_id degree_type                       subject  \
# 0   1    p:6117         MBA                           NaN
# 1   2    p:6136          BA               English, French
# 2   3    p:6136          MS            Mass Communication
# 3   4    p:6005          MS           Internet Technology
# 4   5    p:5832         BCS  Computer Science, Psychology
#
#                         institution graduated_at           created_at  \
# 0                               NaN          NaN  2008-02-19 03:17:36
# 1  Washington University, St. Louis   1990-01-01  2008-02-19 17:58:31
# 2                 Boston University   1992-01-01  2008-02-19 17:58:31
# 3           University of Greenwich   2006-01-01  2008-02-19 23:40:40
# 4                   Rice University          NaN  2008-02-20 05:28:09
#
#             updated_at
# 0  2008-02-19 03:17:36
# 1  2008-02-25 00:23:55
# 2  2008-02-25 00:23:55
# 3  2008-02-25 00:23:55
# 4  2008-02-20 05:28:09

# %%
degrees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109610 entries, 0 to 109609
# Data columns (total 8 columns):
# id              109610 non-null int64
# object_id       109610 non-null object
# degree_type     98392 non-null object
# subject         81298 non-null object
# institution     109555 non-null object
# graduated_at    58054 non-null object
# created_at      109610 non-null object
# updated_at      109610 non-null object
# dtypes: int64(1), object(7)
# memory usage: 6.7+ MB

# %%
def degree_clean(x):
    x_lower = str(x).lower()
    if "phd" in x_lower:
        return "PhD"
    if "ph.d" in x_lower:
        return "PhD"
    if x == "MENG" or x=="MSE" or x=="ME" or x_lower=='master of engineering' or x_lower=="m.s."\
    or x_lower=="m.s" or x_lower=="m.e." or x_lower=="mcs" or x_lower=="mca" or x_lower=="msme"\
    or x_lower=="masc" or x_lower=="m.s.e" or x_lower=="master of science":
        return "MS"
    if x=="M.S.Eng":
        return 'MS'

    if x_lower=="master degree" or x_lower=="masters" or x_lower=="masters degree" or x_lower=="maitrise"\
    or x_lower=="magister" or x_lower=="deug":
        return "Master"

    if x_lower=="diploma" or x_lower=="diplom" or x_lower=="certificate" or x_lower=="certification"\
    or x_lower=='honours' or x_lower=="minor" or x_lower=='fellowship' or x_lower=="incomplete"\
    or x_lower=="honors" or x_lower=="laurea" or x_lower=="cfa" or x_lower=="unknown"\
    or x_lower=="major" or x_lower=="specialist" or x_lower=='advanced management program'\
    or x_lower=="exchange" or x_lower=="hsc" or x_lower=="entrepreneurship" \
    or x_lower=="international baccalaureate" or x_lower=="amp" or x_lower=="diplom-kaufmann" or \
    x_lower=="certified" or x_lower=="diplom kaufmann":
        return np.nan

    if x=="Bachelor of Arts (B.A.)" or x=="BA / BA (Hons)" or x=="AB" or x=="A.B.":
        return "BA"

    if x=="Bachelor of Science (B.S.)" or x=="BE" or x_lower=="bsme" or x=="BENG" or x_lower=="b.s"\
    or x_lower=="bachelors in engineering" or x_lower=="bachelors of engineering" or x_lower=="bca" or \
    x_lower=="bachelor of information technolo" or x_lower=="bmath" or x_lower=="bee":
        return "BS"
    if x=="Master of Business Administratio":
        return "MBA"
    if x == "B of Eng" or x=="Bachelor of Civil Engineering" or x=="B.S. in Electrical Engineering" \
    or x=="BS, Civil Engineering" or x_lower=="bsc" or x_lower=='bcs':
        return "BS"

    if x_lower=="bachelors" or x_lower=="bachelor of economics":
        return "Bachelor"
    if x_lower=='s.b.':
        return "BS"
    if "bachelor of business administrat" in x_lower:
        return 'BBA'
    if x_lower=='bachelor of technology (btech':
        return "BTECH"
    if x_lower=="chartered accountant" or x_lower=="cpa" or x_lower=="ca" or x_lower=="hnd"\
    or x_lower=="aca" or x_lower=="professional certificate" or x_lower=="bts":
        return "Professional"
    if x_lower=="doctor of philosophy" or x_lower=="postdoctoral" or x_lower=="post doc" or x_lower=="d.phil"\
    or x_lower=="dr" or x_lower=="dr." or x_lower=="dea" or x_lower=="dphil":
        return "PhD"
    if x_lower=="juris doctor" or x_lower=="doctor of law (jd)" or x_lower=="j.d.":
        return"JD"

    if "doctorate" in x_lower:
        return "PhD"
    if "bachelor of laws" in x_lower:
        return "LLB"
    if x_lower=="sb":
        return "BS"
    if "executive" in x_lower:
        return "Executive"
    if "high school" in x_lower:
        return np.nan
    if x_lower=="aa" or x_lower=="as" or x_lower=="aas" or x_lower=="dec":
        return "Associate"
    if x_lower=="doctor of medicine":
        return"MD"
    if x_lower=="s.m." or x_lower=="s.m" or x_lower=="sm":
        return "MS"
    if x_lower=="sb" or x_lower=='s.b.' or x_lower=="sc.b." or x_lower=="s.b" or x_lower=="scb":
        return "BS"
    if x=="Bachelor of Technology (B.Tech.)" or x=="Bachelors of Technology":
        return"BTECH"

    if "masters science" in x_lower:
        return "MS"
    if "m.tech" in x_lower:
        return "MTECH"
    if "m.d." in x_lower:
        return "MD"
    if "msc" in x_lower:
        return 'MS'
    if "/ms" in x_lower:
        return "MS"
    if ", ms" in x_lower:
        return "MS"
    if "m.eng" in x_lower :
        return "MS"
    if "ms " in x_lower:
        return "MS"
    if all(c in x_lower for c in ["post","doc"]):
        return "PhD"
    if all(c in x_lower for c in ["post","grad"]):
        return "Graduate"

    if "BA" in str(x):
        if "BBA" in str(x):
            return "BBA"
        elif "MBA" in str(x):
            return "MBA"
        else:
            return "BA"
    if "B.A" in str(x):
        if "B.B.A" in str(x):
            return "BBA"
        elif "M.B.A" in str(x):
            return "MBA"
        else:
            return "BA"

    if "bs " in x_lower:
        return "BS"
    if "bs." in x_lower:
        return 'BS'
    if "bme " in x_lower:
        return "BS"
    if all(c in x_lower for c in ["bachelor","art"]):
        return "BA"
    if all(c in x_lower for c in ["bachelor","science"]):
        return "BS"
    if all(c in x_lower for c in ["bachelor","degree"]):
        return "Bachelor"
    if "bachlor" in x_lower:
        return "Bachelor"
    if "bachellor" in x_lower:
        return "Bachelor"

    if "b.s." in x_lower:
        return "BS"
    if "b. s." in x_lower:
        return "BS"
    if "b.s." in x_lower:
        return "BS"
    if "b. s." in x_lower:
        return "BS"
    if "bs" in str(x).lower():
        return "BS"



    if x_lower=="mem" or x_lower=="mim":
        return "MM"
    if x_lower=="graduation" or x_lower=="diploma" or x_lower=="graduated" or \
    x_lower=="business administration" \
    or x_lower=="business" or x_lower =="marketing" or x_lower=="undergrad" or x_lower=="finance"\
    or x_lower=="economics" or x_lower=="electrical engineering" or x_lower=="law"\
    or x_lower=="management" or x_lower=="it" or x_lower=="cs" \
    or x_lower=="business management"\
    or x_lower=="license" or x_lower=="licence" or x_lower=="commerce" or x_lower=="licentiate"\
    or x_lower=="information technology" or x_lower=="licenciado":
        x= 'Undergraduate'
    if x_lower=="graduate" or x_lower=="graduate diploma" or x_lower=='post graduate' \
    or x_lower=="postgraduate" or x_lower=="post graduate diploma" or x_lower=="advanced diploma"\
    or x_lower=="postgraduation" or x_lower=="post graduation" or x_lower=='graduate certificate'\
    or x_lower=="med" or x_lower=="pgdbm" or x_lower=="pg" or x_lower=="pgdm" or x_lower=="dess"\
    or x_lower=="engineering" or x_lower=="engineer" or x_lower=="dipl-ing"\
    or x_lower=="computer engineering" or x_lower=="mechanical engineering":
        return "Graduate"

    if "llb" in str(x).lower():
        return "LLB"

    if x_lower=="am":
        return "MA"

    if "certificate" in str(x).lower():
        return np.nan

    if x_lower=="bcom" or x_lower=="bm":
        x="BBA"
    if "bach" in str(x).lower():
        x="Bachelor"
    if "B." in str(x):
        if "M.B.A." in str(x):
            return "MBA"
        else:
            return "Bachelor"
    if "master" in str(x).lower():
        return "Master"
    if "M." in str(x):
        return "Master"
    if "engineering" in str(x).lower():
        x="Undergraduate"
    if "engineer" in str(x).lower():
        x="Undergraduate"
    if "baccalaureate" in str(x).lower():
        x=np.nan
    if "Ing" in str(x):
        x="Graduate"
    if "diploma" in str(x).lower():
        x=np.nan
    if "MA" in str(x):
        x="MA"
    if "ME" in str(x):
        x="MS"
    if "J.D" in str(x):
        x="JD"
    if "JD" in str(x):
        x="JD"
    if "MS" in str(x):
        x="MS"
    if "Eng" in str(x):
        x="Graduate"
    if "MPhil" in str(x):
        x="MPHIL"
    if "MBA " in str(x):
        x="MBA"
    if "hon" in str(x).lower():
        x=np.nan

    return x

# %%
def degree_type_clean():
    degrees = pd.read_csv(os.path.join('..',"raw_data","degrees.csv"))
    degrees["degree_type_clean"] = degrees.degree_type.map(degree_clean)
    degrees_clean = pd.DataFrame(degrees["degree_type_clean"].value_counts())
    def cleaning(x):
        try:
            if degrees_clean.loc[x].degree_type_clean >= 10:
                return x
            else:
                return np.nan
        except:
            return np.nan

    degrees["degree_type_clean"]= degrees["degree_type_clean"].map(cleaning)

    return degrees

# %%
degree_type_clean()
# Out:
#             id object_id          degree_type  \
# 0            1    p:6117                  MBA
# 1            2    p:6136                   BA
# 2            3    p:6136                   MS
# 3            4    p:6005                   MS
# 4            5    p:5832                  BCS
# 5            6    p:1017                   BS
# 6            7    p:6176                   BS
# 7            8    p:5412                   MS
# 8            9    p:1243                   BA
# 9           10    p:6265                   BS
# 10          11    p:6328           Foundation
# 11          12    p:6329                   MA
# 12          13    p:2351                  LLB
# 13          14    p:2351                   BA
# 14          15    p:5471                   MS
# 15          16    p:2005                  PhD
# 16          17    p:6453                  MBA
# 17          18    p:6453                   BA
# 18          19    p:5991                  BFA
# 19          20    p:1017                  MBA
# 20          21    p:6497                   BS
# 21          22    p:6497                   MS
# 22          23     p:174                   BA
# 23          24    p:3791                   BA
# 24          25    p:6496                   BS
# 25          26    p:6496                   MS
# 26          27    p:6536                   BA
# 27          28    p:6559                   BA
# 28          29    p:6579                   BE
# 29          30    p:6591      MBA With Honors
# ...        ...       ...                  ...
# 109580  109581  p:268513                   BS
# 109581  109582  p:268513                  MBA
# 109582  109583  p:268514            bachelors
# 109583  109584  p:268516                   BS
# 109584  109585  p:268516                   JD
# 109585  109586  p:268396                  NaN
# 109586  109587  p:268397                   JD
# 109587  109588  p:268397                  BBA
# 109588  109589  p:268517                 B.S.
# 109589  109590  p:268517               M.B.A.
# 109590  109591  p:268517                 J.D.
# 109591  109592  p:268519  Bachelor of Science
# 109592  109593  p:268519    Master of Science
# 109593  109594  p:268519         Juris Doctor
# 109594  109595  p:268519                  MBA
# 109595  109596  p:268520                 B.S.
# 109596  109597  p:268520                 M.S.
# 109597  109598  p:268521                   BS
# 109598  109599  p:268521                  MBA
# 109599  109600  p:158143                  MBA
# 109600  109601  p:158143                 B.A.
# 109601  109602  p:268524              Masters
# 109602  109603  p:268524                 B.S.
# 109603  109604  p:268524              Masters
# 109604  109605  p:268589                 B.S.
# 109605  109606  p:268589                  CPA
# 109606  109607  p:268527              MS & BS
# 109607  109608  p:268527                  PhD
# 109608  109609  p:268528                 B.S.
# 109609  109610  p:268528                 J.D.
#
#                                                 subject  \
# 0                                                   NaN
# 1                                       English, French
# 2                                    Mass Communication
# 3                                   Internet Technology
# 4                          Computer Science, Psychology
# 5                                      Computer Science
# 6                                      Computer Science
# 7                                              Politics
# 8                    International Business & Marketing
# 9                                             Economics
# 10                    Computing and Internet Technology
# 11                                 Physics & Philosophy
# 12                                                  Law
# 13                                            Economics
# 14                        Media & Knowledge Engineering
# 15                                              Finance
# 16                                                  NaN
# 17                           History, Political Science
# 18                        Computer Science, Photography
# 19                            Entrepreneurship, Finance
# 20                      Engineering and Applied Science
# 21                                     Computer Science
# 22                                    Political Science
# 23                                       Social Studies
# 24                       Computer Science & Engineering
# 25                Computer Science Software Engineering
# 26                                     Computer Science
# 27      Communications, Publishing, Social Anthropology
# 28                                                   EE
# 29                           Entrepreneurial Management
# ...                                                 ...
# 109580                             Financial Management
# 109581                                 Finance, General
# 109582                                        economics
# 109583                                          finance
# 109584                                              NaN
# 109585                                          Finance
# 109586                                              NaN
# 109587                                          Finance
# 109588                                      Engineering
# 109589                                              NaN
# 109590                                              NaN
# 109591                                      Engineering
# 109592                                      Engineering
# 109593                                              NaN
# 109594                                 Finance, General
# 109595                                          physics
# 109596                                          Physics
# 109597                           Mechanical Engineering
# 109598                                              NaN
# 109599                                              NaN
# 109600                                              NaN
# 109601                          Business Administration
# 109602                                              NaN
# 109603                          Business Administration
# 109604                                       Accounting
# 109605                                              NaN
# 109606                                      Engineering
# 109607                                      Engineering
# 109608                           Electrical Engineering
# 109609                                              NaN
#
#                                               institution graduated_at  \
# 0                                                     NaN          NaN
# 1                        Washington University, St. Louis   1990-01-01
# 2                                       Boston University   1992-01-01
# 3                                 University of Greenwich   2006-01-01
# 4                                         Rice University          NaN
# 5                                 Northeastern University   1988-01-01
# 6                       Rochester Institute of Technology   2002-01-01
# 7                                 University of Cambridge   2002-01-01
# 8                                    University of Oregon   1997-01-01
# 9                              University of Pennsylvania   1989-01-01
# 10                                 Bournemouth University   2008-01-01
# 11                                University of Cambridge          NaN
# 12                    University of Toronto School of Law   1993-01-01
# 13                                   Princeton University   1990-01-01
# 14                              TU Delft, The Netherlands   2007-01-01
# 15                                    Tel Aviv University   1999-01-01
# 16                                    University of Texas   2004-01-01
# 17                             Louisiana State University   1996-01-01
# 18                              New York University (NYU)   2005-01-01
# 19                                         Babson College   1995-01-01
# 20                     California Institute of Technology          NaN
# 21           University of California, Los Angeles (UCLA)          NaN
# 22                                        Yale University   2005-01-01
# 23                                     Harvard University   2005-01-01
# 24           University of California, Los Angeles (UCLA)   1997-01-01
# 25           University of California, Los Angeles (UCLA)   1999-01-01
# 26                         University of Nevada Las Vegas   1992-01-01
# 27            Simon Fraser University, Ryerson University          NaN
# 28                            Bangalore University, India   1992-01-01
# 29        University of Pennsylvania - The Wharton School   2008-01-01
# ...                                                   ...          ...
# 109580                                 Clemson University   1982-01-01
# 109581  Southern Methodist University - Cox School of ...   1983-01-01
# 109582                     University of Colorado/Boulder          NaN
# 109583  Wharton School of Business , University of Pen...          NaN
# 109584                                 Harvard Law School          NaN
# 109585  The University of Texas at Austin - The Red Mc...   2005-01-01
# 109586              The University of Texas School of Law   2008-01-01
# 109587  The University of Texas at Austin - The Red Mc...   1999-01-01
# 109588                        University of Massachusetts          NaN
# 109589                        University of Massachusetts          NaN
# 109590          University of New Hampshire School of Law          NaN
# 109591                 Auburn University, Auburn, Alabama   1977-01-01
# 109592                 Auburn University, Auburn, Alabama   1978-01-01
# 109593          Loyola University, New Orleans, Louisiana   1985-01-01
# 109594             Rutgers University, Newark, New Jersey   1998-01-01
# 109595                                  Waseda University          NaN
# 109596                                  Waseda University          NaN
# 109597            University of California, Santa Barbara   2002-01-01
# 109598  University of California, Irvine - The Paul Me...   2006-01-01
# 109599                    Case Western Reserve University          NaN
# 109600                    Case Western Reserve University          NaN
# 109601                                     Wharton School          NaN
# 109602               University of California at Berkeley          NaN
# 109603  Wharton School of Business , University of Pen...          NaN
# 109604                              Iowa State University          NaN
# 109605  American Institute of Certtified Public Accoun...          NaN
# 109606               South China University of Technology          NaN
# 109607                                Clarkson University          NaN
# 109608                          Colorado State University          NaN
# 109609              University of San Diego School of Law          NaN
#
#                  created_at           updated_at degree_type_clean
# 0       2008-02-19 03:17:36  2008-02-19 03:17:36               MBA
# 1       2008-02-19 17:58:31  2008-02-25 00:23:55                BA
# 2       2008-02-19 17:58:31  2008-02-25 00:23:55                MS
# 3       2008-02-19 23:40:40  2008-02-25 00:23:55                MS
# 4       2008-02-20 05:28:09  2008-02-20 05:28:09                BS
# 5       2008-02-21 01:31:01  2008-02-25 00:23:55                BS
# 6       2008-02-21 01:31:34  2008-02-25 00:23:55                BS
# 7       2008-02-21 20:01:32  2008-02-25 00:23:55                MS
# 8       2008-02-22 08:16:50  2013-07-27 08:48:01                BA
# 9       2008-02-22 08:27:15  2008-02-25 00:23:55                BS
# 10      2008-02-22 12:38:32  2008-02-25 00:23:55               NaN
# 11      2008-02-22 13:16:09  2008-02-22 13:16:09                MA
# 12      2008-02-24 00:57:59  2008-02-25 00:23:55               LLB
# 13      2008-02-24 00:58:38  2008-02-25 00:23:55                BA
# 14      2008-02-24 01:17:35  2008-02-25 00:23:55                MS
# 15      2008-02-24 01:19:59  2008-02-25 00:23:55               PhD
# 16      2008-02-24 05:38:24  2008-02-25 00:23:55               MBA
# 17      2008-02-24 05:38:24  2008-02-25 00:23:55                BA
# 18      2008-02-24 19:42:44  2008-02-25 00:23:55               BFA
# 19      2008-02-24 19:48:12  2008-02-25 00:23:55               MBA
# 20      2008-02-25 01:07:15  2008-02-25 01:07:15                BS
# 21      2008-02-25 01:07:15  2008-02-25 01:07:15                MS
# 22      2008-02-25 01:37:47  2013-07-15 19:53:08                BA
# 23      2008-02-25 07:33:25  2008-02-25 07:33:25                BA
# 24      2008-02-25 07:39:47  2008-02-25 07:39:47                BS
# 25      2008-02-25 07:39:47  2008-02-25 07:39:47                MS
# 26      2008-02-25 15:12:35  2008-02-25 15:12:35                BA
# 27      2008-02-25 22:45:56  2008-03-05 00:08:05                BA
# 28      2008-02-26 03:32:33  2008-02-26 03:32:33                BS
# 29      2008-02-26 16:05:03  2013-09-17 05:04:09               MBA
# ...                     ...                  ...               ...
# 109580  2013-12-12 12:06:31  2013-12-12 12:06:31                BS
# 109581  2013-12-12 12:07:14  2013-12-12 12:07:14               MBA
# 109582  2013-12-12 12:14:26  2013-12-12 12:14:26          Bachelor
# 109583  2013-12-12 12:20:49  2013-12-12 12:20:49                BS
# 109584  2013-12-12 12:21:08  2013-12-12 12:21:08                JD
# 109585  2013-12-12 12:23:58  2013-12-12 12:23:58               NaN
# 109586  2013-12-12 12:26:20  2013-12-12 12:26:20                JD
# 109587  2013-12-12 12:26:20  2013-12-12 12:26:20               BBA
# 109588  2013-12-12 12:28:03  2013-12-12 12:28:03                BS
# 109589  2013-12-12 12:28:23  2013-12-12 12:28:23               MBA
# 109590  2013-12-12 12:28:42  2013-12-12 12:28:42                JD
# 109591  2013-12-12 12:43:14  2013-12-12 12:43:14                BS
# 109592  2013-12-12 12:43:47  2013-12-12 12:43:47                MS
# 109593  2013-12-12 12:44:53  2013-12-12 12:44:53                JD
# 109594  2013-12-12 12:45:45  2013-12-12 12:45:45               MBA
# 109595  2013-12-12 13:56:08  2013-12-12 13:56:08                BS
# 109596  2013-12-12 13:56:37  2013-12-12 13:56:37                MS
# 109597  2013-12-12 14:01:29  2013-12-12 14:01:29                BS
# 109598  2013-12-12 14:02:21  2013-12-12 14:02:21               MBA
# 109599  2013-12-12 14:15:42  2013-12-12 14:15:42               MBA
# 109600  2013-12-12 14:15:42  2013-12-12 14:15:42                BA
# 109601  2013-12-12 14:21:11  2013-12-12 14:21:11            Master
# 109602  2013-12-12 14:21:38  2013-12-12 14:21:38                BS
# 109603  2013-12-12 14:22:33  2013-12-12 14:22:33            Master
# 109604  2013-12-12 14:28:58  2013-12-12 14:28:58                BS
# 109605  2013-12-12 14:28:58  2013-12-12 14:28:58      Professional
# 109606  2013-12-12 14:31:21  2013-12-12 14:31:21                MS
# 109607  2013-12-12 14:31:48  2013-12-12 14:31:48               PhD
# 109608  2013-12-12 14:38:15  2013-12-12 14:38:15                BS
# 109609  2013-12-12 14:38:33  2013-12-12 14:38:33                JD
#
# [109610 rows x 9 columns]
